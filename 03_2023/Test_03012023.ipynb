# %%
# import PyTorch and its related packages
import torch as T
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

import torch

import torchvision
import torchvision.transforms as transforms

from torchvision import transforms
from torchvision.datasets import ImageFolder

from tqdm.notebook import tqdm

from sklearn.metrics import confusion_matrix

#mcc implementation
from torchmetrics.classification import MultilabelMatthewsCorrCoef

# set default device based on CUDA's availability
device = 'cuda' if T.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda'

# %%
transform = transforms.Compose(
    [transforms.Resize((448,448)),
     transforms.RandomHorizontalFlip(p=0.5),
     transforms.RandomVerticalFlip(p=0.5),
     transforms.ToTensor(),
     transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))])

train_transforms = transforms.Compose(
    [transforms.Resize((448,448)),
    transforms.ColorJitter(),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomVerticalFlip(p=0.5),
    transforms.ToTensor(), 
    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))])

batch_size = 64
#image_size = (224, 224, 3)

train_set = ImageFolder('C:/Users/heuma/Desktop/Work/Reseaux_test/Dataset_Kaggle/output/train', transform=train_transforms)
validation_set = ImageFolder('C:/Users/heuma/Desktop/Work/Reseaux_test/Dataset_Kaggle/output/val', transform=transform)
test_set = ImageFolder('C:/Users/heuma/Desktop/Work/Reseaux_test/Dataset_Kaggle/output/test', transform=transform)

#train_set = train_ds
train_loader = T.utils.data.DataLoader(train_set, batch_size=batch_size,shuffle=True, num_workers=8)

#validation_set = validation_ds
validation_loader = T.utils.data.DataLoader(validation_set, batch_size=batch_size,shuffle=True, num_workers=8)

#test_set = test_ds
test_loader = T.utils.data.DataLoader(test_set, batch_size=batch_size,shuffle=True, num_workers=8)

# %%
class NewNetwork(nn.Module):
    def __init__(self, num_classes=291):
        super(NewNetwork, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=11, stride=4, padding=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
            nn.Dropout(p=0.5),
            nn.Conv2d(64, 128, kernel_size=9, padding=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
            nn.Dropout(p=0.5),
            nn.Conv2d(128, 256, kernel_size=7, padding=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
            nn.Dropout(p=0.5),
            nn.Conv2d(256, 512, kernel_size=5, padding=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
            nn.Dropout(p=0.5),
            nn.Conv2d(512, 1024, kernel_size=3, padding=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
            nn.Dropout(p=0.5)
        )
        self.classifier = nn.Sequential(
            nn.Dropout(p=0.5),
            nn.Linear(36 * 16 * 16, 1000), #mettre 128 quand il y a 5 couches
            nn.PReLU(),
            nn.Dropout(p=0.5),
            nn.Linear(1000, 1000),
            nn.PReLU(),
            nn.Linear(1000, num_classes),
        )

    def forward(self, x):
        x = self.features(x)
        x = x.view(x.shape[0], -1)
        x = self.classifier(x)
        return x

# %%
net = NewNetwork()
net.to(device)
# Out:
# NewNetwork(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Conv2d(64, 128, kernel_size=(9, 9), stride=(1, 1), padding=(2, 2))
#     (5): ReLU(inplace=True)
#     (6): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Dropout(p=0.5, inplace=False)
#     (8): Conv2d(128, 256, kernel_size=(7, 7), stride=(1, 1), padding=(2, 2))
#     (9): ReLU(inplace=True)
#     (10): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (11): Dropout(p=0.5, inplace=False)
#     (12): Conv2d(256, 512, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (13): ReLU(inplace=True)
#     (14): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (15): Dropout(p=0.5, inplace=False)
#     (16): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#     (17): ReLU(inplace=True)
#     (18): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (19): Dropout(p=0.5, inplace=False)
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=9216, out_features=1000, bias=True)
#     (2): PReLU(num_parameters=1)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=1000, out_features=1000, bias=True)
#     (5): PReLU(num_parameters=1)
#     (6): Linear(in_features=1000, out_features=291, bias=True)
#   )
# )

# %%
criterion = nn.CrossEntropyLoss()

# also the optimizer
optimizer = optim.Adam(net.parameters(), lr=0.0001)

#dynamic learning rate
#scheduler = optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.9)

# %%
train_loss = []
validation_loss = []
train_acc = []
validation_acc = []

test_acc = []

mcc_list = []

lrs = []
steps = []

epoch_affichage = 1

# Initialize the prediction and label lists(tensors)
predlist=torch.zeros(0,dtype=torch.long, device='cpu')
lbllist=torch.zeros(0,dtype=torch.long, device='cpu')

for epoch in tqdm(range(0, 51)):  # loop over the dataset multiple times
    
    running_loss = .0
    correct = 0
    total = 0
    for i, data in enumerate(train_loader):
        # get the inputs
        inputs, labels = data
        if device == 'cuda':
            inputs, labels = inputs.to(device), labels.to(device)

        # reset the parameter gradients
        optimizer.zero_grad()

        # forward
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        # backward
        loss.backward()
        # optimize
        optimizer.step()
        
        running_loss += loss.item()
        _, predicted = T.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        
    running_loss /= len(train_loader)
    train_loss.append(running_loss)
    running_acc = correct / total
    train_acc.append(running_acc)
    
    """
    print("predicted = ",predicted)
    print("labels = ",labels)
    """
    
    #MCC implementation
    """
    metric_mcc = MultilabelMatthewsCorrCoef(num_labels=291)
    metric_mcc(predicted, labels)
    mcc_list.append(metric_mcc)
    """
    
    #zone pour mettre le learning rate dynamique
    """
    steps.append(epoch)
    lrs.append(scheduler.get_last_lr()[0])
    scheduler.step()
    """
    
    if epoch % epoch_affichage == 0: #ici changer pour la frequence d'affichage
        print('\nEpoch: {}'.format(epoch))
        print('Train Acc. => {:.3f}%'.format(100 * running_acc), end=' | ')
        print('Train Loss => {:.5f}'.format(running_loss))
    
    # evaluate on the validation set
    # note this is usually performed on the validation set
    # for simplicity we just evaluate it on the validation set
    with T.no_grad():
        correct = 0
        total = 0
        validation_running_loss = .0
        for data in validation_loader:
            inputs, labels = data
            if device == 'cuda':
                inputs, labels = inputs.to(device), labels.to(device)
            outputs = net(inputs)
            loss = criterion(outputs, labels)
            validation_running_loss += loss.item()
            _, predicted = T.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            
            if epoch == 50: # a changer si besoin d'afficher la matrice de confusion, a mettre à epoch-1
                # Append batch prediction results
                predlist=torch.cat([predlist,predicted.view(-1).cpu()])
                lbllist=torch.cat([lbllist,labels.view(-1).cpu()])

        validation_running_loss /= len(validation_loader)
        validation_loss.append(validation_running_loss)
        validation_running_acc = correct / total
        validation_acc.append(validation_running_acc)
        
        if epoch % epoch_affichage == 0: #ici changer pour la frequence d'affichage
            print('validation Acc.  => {:.3f}%'.format(100 * validation_running_acc), end=' | ')
            print('validation Loss  => {:.5f}'.format(validation_running_loss))

    with torch.no_grad():
        correct_t = 0
        total_t = 0
        for data in test_loader:
            inputs, labels = data
            inputs, labels = inputs.to('cuda'), labels.to('cuda')
            outputs = net(inputs)
            _, predicted = torch.max(outputs.data, 1)
            total_t += labels.size(0)
            correct_t += (predicted == labels).sum().item()
            
            running_acc_t = correct_t / total_t
        test_acc.append(running_acc_t)
    
        if epoch % epoch_affichage == 0: #ici changer pour la frequence d'affichage
            print('Accuracy of the network on test images: %d %%' % (100 * correct_t / total_t))

print('Finished Training')
# Out:
#   0%|          | 0/51 [00:00<?, ?it/s]
# Epoch: 0
# Train Acc. => 1.327% | Train Loss => 5.40758
# validation Acc.  => 3.194% | validation Loss  => 4.86360
# Accuracy of the network on test images: 3 %
#
# Epoch: 1
# Train Acc. => 5.540% | Train Loss => 4.30000
# validation Acc.  => 9.516% | validation Loss  => 3.76395
# Accuracy of the network on test images: 9 %
#
# Epoch: 2
# Train Acc. => 13.758% | Train Loss => 3.45977
# validation Acc.  => 18.645% | validation Loss  => 3.11548
# Accuracy of the network on test images: 18 %
#
# Epoch: 3
# Train Acc. => 21.864% | Train Loss => 2.91501
# validation Acc.  => 24.742% | validation Loss  => 2.76521
# Accuracy of the network on test images: 25 %
#
# Epoch: 4
# Train Acc. => 29.028% | Train Loss => 2.53519
# validation Acc.  => 32.258% | validation Loss  => 2.35307
# Accuracy of the network on test images: 32 %
#
# Epoch: 5
# Train Acc. => 34.366% | Train Loss => 2.27860
# validation Acc.  => 38.194% | validation Loss  => 2.09394
# Accuracy of the network on test images: 39 %
#
# Epoch: 6
# Train Acc. => 40.233% | Train Loss => 2.03603
# validation Acc.  => 41.790% | validation Loss  => 1.96403
# Accuracy of the network on test images: 41 %
#
# Epoch: 7
# Train Acc. => 44.624% | Train Loss => 1.86343
# validation Acc.  => 47.935% | validation Loss  => 1.73406
# Accuracy of the network on test images: 47 %
#
# Epoch: 8
# Train Acc. => 48.453% | Train Loss => 1.71239
# validation Acc.  => 49.790% | validation Loss  => 1.66279
# Accuracy of the network on test images: 50 %
#
# Epoch: 9
# Train Acc. => 51.656% | Train Loss => 1.59608
# validation Acc.  => 52.177% | validation Loss  => 1.58657
# Accuracy of the network on test images: 51 %
#
# Epoch: 10
# Train Acc. => 54.272% | Train Loss => 1.48851
# validation Acc.  => 54.839% | validation Loss  => 1.47759
# Accuracy of the network on test images: 54 %
#
# Epoch: 11
# Train Acc. => 56.211% | Train Loss => 1.41500
# validation Acc.  => 58.403% | validation Loss  => 1.38711
# Accuracy of the network on test images: 57 %
#
# Epoch: 12
# Train Acc. => 58.193% | Train Loss => 1.34572
# validation Acc.  => 56.903% | validation Loss  => 1.38564
# Accuracy of the network on test images: 57 %
#
# Epoch: 13
# Train Acc. => 59.745% | Train Loss => 1.27936
# validation Acc.  => 58.065% | validation Loss  => 1.36513
# Accuracy of the network on test images: 58 %
#
# Epoch: 14
# Train Acc. => 61.298% | Train Loss => 1.23787
# validation Acc.  => 60.694% | validation Loss  => 1.26756
# Accuracy of the network on test images: 61 %
#
# Epoch: 15
# Train Acc. => 62.465% | Train Loss => 1.18762
# validation Acc.  => 64.210% | validation Loss  => 1.16285
# Accuracy of the network on test images: 63 %
#
# Epoch: 16
# Train Acc. => 64.180% | Train Loss => 1.13681
# validation Acc.  => 62.903% | validation Loss  => 1.22273
# Accuracy of the network on test images: 63 %
#
# Epoch: 17
# Train Acc. => 64.933% | Train Loss => 1.10844
# validation Acc.  => 66.032% | validation Loss  => 1.11957
# Accuracy of the network on test images: 65 %
#
# Epoch: 18
# Train Acc. => 66.174% | Train Loss => 1.06661
# validation Acc.  => 67.097% | validation Loss  => 1.06301
# Accuracy of the network on test images: 66 %
#
# Epoch: 19
# Train Acc. => 67.159% | Train Loss => 1.03587
# validation Acc.  => 66.629% | validation Loss  => 1.07569
# Accuracy of the network on test images: 66 %
#
# Epoch: 20
# Train Acc. => 67.687% | Train Loss => 1.01076
# validation Acc.  => 67.532% | validation Loss  => 1.04467
# Accuracy of the network on test images: 68 %
#
# Epoch: 21
# Train Acc. => 68.923% | Train Loss => 0.97523
# validation Acc.  => 68.742% | validation Loss  => 1.01025
# Accuracy of the network on test images: 68 %
#
# Epoch: 22
# Train Acc. => 69.479% | Train Loss => 0.95257
# validation Acc.  => 67.694% | validation Loss  => 1.05169
# Accuracy of the network on test images: 68 %
#
# Epoch: 23
# Train Acc. => 70.440% | Train Loss => 0.92169
# validation Acc.  => 68.097% | validation Loss  => 1.04961
# Accuracy of the network on test images: 68 %
#
# Epoch: 24
# Train Acc. => 71.134% | Train Loss => 0.90131
# validation Acc.  => 70.484% | validation Loss  => 0.96758
# Accuracy of the network on test images: 70 %
#
# Epoch: 25
# Train Acc. => 71.625% | Train Loss => 0.88612
# validation Acc.  => 71.629% | validation Loss  => 0.92716
# Accuracy of the network on test images: 71 %
#
# Epoch: 26
# Train Acc. => 72.525% | Train Loss => 0.85495
# validation Acc.  => 69.935% | validation Loss  => 0.97272
# Accuracy of the network on test images: 69 %
#
# Epoch: 27
# Train Acc. => 72.766% | Train Loss => 0.84414
# validation Acc.  => 69.984% | validation Loss  => 0.96517
# Accuracy of the network on test images: 70 %
#
# Epoch: 28
# Train Acc. => 72.914% | Train Loss => 0.82709
# validation Acc.  => 71.403% | validation Loss  => 0.93871
# Accuracy of the network on test images: 71 %
#
# Epoch: 29
# Train Acc. => 73.579% | Train Loss => 0.80972
# validation Acc.  => 72.581% | validation Loss  => 0.91313
# Accuracy of the network on test images: 71 %
#
# Epoch: 30
# Train Acc. => 74.176% | Train Loss => 0.80025
# validation Acc.  => 71.952% | validation Loss  => 0.90303
# Accuracy of the network on test images: 72 %
#
# Epoch: 31
# Train Acc. => 74.702% | Train Loss => 0.78139
# validation Acc.  => 72.694% | validation Loss  => 0.88983
# Accuracy of the network on test images: 72 %
#
# Epoch: 32
# Train Acc. => 75.177% | Train Loss => 0.76091
# validation Acc.  => 72.065% | validation Loss  => 0.88529
# Accuracy of the network on test images: 72 %
#
# Epoch: 33
# Train Acc. => 75.875% | Train Loss => 0.74457
# validation Acc.  => 73.758% | validation Loss  => 0.84058
# Accuracy of the network on test images: 73 %
#
# Epoch: 34
# Train Acc. => 75.869% | Train Loss => 0.74438
# validation Acc.  => 74.742% | validation Loss  => 0.81664
# Accuracy of the network on test images: 73 %
#
# Epoch: 35
# Train Acc. => 76.382% | Train Loss => 0.72231
# validation Acc.  => 73.694% | validation Loss  => 0.85802
# Accuracy of the network on test images: 73 %
#
# Epoch: 36
# Train Acc. => 76.789% | Train Loss => 0.71466
# validation Acc.  => 74.000% | validation Loss  => 0.82453
# Accuracy of the network on test images: 74 %
#
# Epoch: 37
# Train Acc. => 77.111% | Train Loss => 0.69704
# validation Acc.  => 73.097% | validation Loss  => 0.87314
# Accuracy of the network on test images: 73 %
#
# Epoch: 38
# Train Acc. => 77.873% | Train Loss => 0.67654
# validation Acc.  => 73.403% | validation Loss  => 0.87292
# Accuracy of the network on test images: 73 %
#
# Epoch: 39
# Train Acc. => 77.553% | Train Loss => 0.68574
# validation Acc.  => 75.355% | validation Loss  => 0.80662
# Accuracy of the network on test images: 74 %
#
# Epoch: 40
# Train Acc. => 78.025% | Train Loss => 0.67216
# validation Acc.  => 74.952% | validation Loss  => 0.82423
# Accuracy of the network on test images: 74 %
#
# Epoch: 41
# Train Acc. => 78.379% | Train Loss => 0.66770
# validation Acc.  => 75.903% | validation Loss  => 0.80197
# Accuracy of the network on test images: 75 %
#
# Epoch: 42
# Train Acc. => 78.419% | Train Loss => 0.65862
# validation Acc.  => 74.032% | validation Loss  => 0.85625
# Accuracy of the network on test images: 74 %
#
# Epoch: 43
# Train Acc. => 78.795% | Train Loss => 0.64865
# validation Acc.  => 74.258% | validation Loss  => 0.84075
# Accuracy of the network on test images: 74 %
#
# Epoch: 44
# Train Acc. => 78.771% | Train Loss => 0.64372
# validation Acc.  => 74.887% | validation Loss  => 0.82253
# Accuracy of the network on test images: 74 %
#
# Epoch: 45
# Train Acc. => 79.307% | Train Loss => 0.63057
# validation Acc.  => 76.774% | validation Loss  => 0.76329
# Accuracy of the network on test images: 76 %
#
# Epoch: 46
# Train Acc. => 79.370% | Train Loss => 0.62320
# validation Acc.  => 74.145% | validation Loss  => 0.84339
# Accuracy of the network on test images: 75 %
#
# Epoch: 47
# Train Acc. => 79.463% | Train Loss => 0.62468
# validation Acc.  => 75.871% | validation Loss  => 0.83757
# Accuracy of the network on test images: 75 %
#
# Epoch: 48
# Train Acc. => 80.070% | Train Loss => 0.60407
# validation Acc.  => 76.839% | validation Loss  => 0.77579
# Accuracy of the network on test images: 77 %
#
# Epoch: 49
# Train Acc. => 80.090% | Train Loss => 0.60564
# validation Acc.  => 76.226% | validation Loss  => 0.76295
# Accuracy of the network on test images: 77 %
#
# Epoch: 50
# Train Acc. => 80.500% | Train Loss => 0.59057
# validation Acc.  => 76.774% | validation Loss  => 0.75792
# Accuracy of the network on test images: 76 %
# Finished Training

# %% [markdown]
# ## Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.plot(train_loss, label='train')
plt.plot(validation_loss, label='validation')
plt.xlabel("epoch")
plt.ylabel("loss values")
plt.title("loss rate's curve")
plt.legend()
plt.show()

# %%
plt.plot(train_acc, label='train')
plt.plot(validation_acc, label='validation')
plt.plot(test_acc, label='test')
plt.xlabel("epoch")
plt.ylabel("accuracy values")
plt.title("accuracy rate's curve")
plt.legend()
plt.show()

# %%
#plt.plot(mcc_list, label='MCC')
#plt.xlabel("epoch")
#plt.ylabel("MCC values")
#plt.title("MCC curve")
#plt.legend()
#plt.show()

# %%
# Confusion matrix
conf_mat=confusion_matrix(lbllist.numpy(), predlist.numpy())
print(conf_mat)
# Out:
# [[11  2  0 ...  0  0  0]
#  [ 0 39  0 ...  0  0  0]
#  [ 0  0 19 ...  0  0  0]
#  ...
#  [ 0  0  0 ... 21  0  0]
#  [ 0  0  0 ...  0 19  0]
#  [ 0  0  0 ...  0  0 30]]

# %%
fig, ax = plt.subplots(figsize=(13,10))
sns.heatmap(conf_mat, annot=False, ax=ax, cmap="BuPu")
# Out:
# <AxesSubplot:>

# %%
# Per-class accuracy
class_accuracy=100*conf_mat.diagonal()/conf_mat.sum(1)
print(class_accuracy)
# Out:
# [ 55.          66.10169492  79.16666667  75.43859649  81.25
#   78.94736842  63.63636364  89.36170213  80.          65.78947368
#   70.          96.07843137  80.85106383  85.71428571  55.55555556
#   87.20930233 100.          92.30769231  45.28301887  68.18181818
#   80.76923077  82.35294118  64.51612903 100.          79.16666667
#    0.          89.36170213 100.          78.57142857 100.
#   83.33333333  73.52941176  91.66666667  90.90909091 100.
#   88.88888889  73.33333333  50.          87.5         27.77777778
#   18.18181818  77.77777778  83.33333333  68.75        50.
#   95.          50.          78.57142857  65.2173913   50.
#   90.90909091  62.5         75.         100.         100.
#   63.63636364  72.72727273  68.          45.45454545  40.
#   64.70588235  40.          45.45454545  59.09090909  71.42857143
#   33.33333333 100.          58.82352941  90.90909091  83.33333333
#   85.71428571  45.          85.          95.83333333  90.47619048
#   89.28571429  70.83333333  85.          93.75        45.45454545
#  100.         100.          90.          83.33333333  60.
#   40.          66.66666667  85.91549296  60.          55.55555556
#   92.85714286  60.          86.66666667  85.45454545  87.5
#   57.14285714  81.25        94.11764706  85.71428571  92.30769231
#   84.21052632  80.          56.75675676  75.          20.
#   80.          80.95238095  86.95652174  83.33333333  80.55555556
#   36.36363636  62.96296296  94.11764706  85.         100.
#   97.2972973   74.07407407  87.5         81.81818182 100.
#   66.66666667  54.54545455  86.2745098   84.21052632  80.95238095
#   93.18181818  90.90909091  57.14285714  78.94736842  60.86956522
#   66.66666667  52.38095238  92.85714286  94.73684211  72.72727273
#   87.5         31.57894737  81.81818182  66.66666667 100.
#   89.18918919  77.77777778 100.          76.92307692  71.875
#  100.          72.22222222  68.75        69.23076923  71.42857143
#   73.33333333  50.          62.5         47.61904762  85.71428571
#   76.47058824  77.41935484  85.          66.66666667  83.33333333
#  100.          92.85714286  80.          81.81818182  83.33333333
#   75.          71.875      100.          66.66666667  92.5
#   69.23076923 100.          84.21052632  42.85714286  61.11111111
#   52.38095238  60.         100.          40.          95.
#   50.         100.          75.          85.71428571  86.84210526
#   66.66666667  31.70731707  89.47368421  91.11111111  80.64516129
#   80.          83.33333333  55.55555556  75.         100.
#   46.15384615  90.90909091  40.          63.63636364  36.36363636
#   65.71428571  63.63636364  83.33333333 100.          89.18918919
#   68.         100.          94.73684211  60.          57.89473684
#   66.66666667  80.          66.66666667  72.72727273  60.60606061
#   58.82352941  92.30769231  89.18918919  54.54545455  83.33333333
#   77.77777778  83.33333333  68.75        41.66666667  63.63636364
#   46.15384615  57.14285714 100.         100.         100.
#   54.54545455  80.          50.          55.55555556  81.25
#    0.          84.61538462  60.          71.60493827  87.5
#   20.          87.75510204  92.          93.75       100.
#   78.          90.         100.          66.66666667  83.87096774
#   78.43137255  72.72727273  55.55555556  71.42857143  20.
#   45.45454545  75.          77.77777778  77.77777778  70.
#   90.          75.          30.76923077  87.5         73.07692308
#   76.47058824  57.14285714   0.          57.89473684  73.33333333
#   20.          35.29411765  67.74193548  88.88888889  88.
#   71.42857143  60.          81.48148148  90.          80.
#   84.          90.90909091  87.5         92.85714286 100.
#   77.77777778 100.         100.          91.30434783  70.37037037
#   75.        ]

# %% [markdown]
# ## Save

# %%
#torch.save(net.state_dict(), "C:/Users/heuma/Desktop/Master/S10/Aurea/Dataset_Kaggle_validation_Train_20-80/dict_Linh_network_1st_try")

# %%
#torch.save(net, "C:/Users/heuma/Desktop/Master/S10/Aurea/Dataset_Kaggle_validation_Train_20-80/Linh_network_entire_model_1st_try")

# %%
"""
from torch.utils.data.dataloader import DataLoader


train_dl = DataLoader(train_set, batch_size, shuffle = True, num_workers = 4, pin_memory = True)

from torchvision.utils import make_grid

def show_batch(dl):
    #Plot images grid of single batch
    for images, labels in dl:
        fig,ax = plt.subplots(figsize = (16,12))
        ax.set_xticks([])
        ax.set_yticks([])
        ax.imshow(make_grid(images,nrow=16).permute(1,2,0))
        break
        
show_batch(train_dl)

"""
# Out:
# '\nfrom torch.utils.data.dataloader import DataLoader\n\n\ntrain_dl = DataLoader(train_set, batch_size, shuffle = True, num_workers = 4, pin_memory = True)\n\nfrom torchvision.utils import make_grid\n\ndef show_batch(dl):\n    #Plot images grid of single batch\n    for images, labels in dl:\n        fig,ax = plt.subplots(figsize = (16,12))\n        ax.set_xticks([])\n        ax.set_yticks([])\n        ax.imshow(make_grid(images,nrow=16).permute(1,2,0))\n        break\n        \nshow_batch(train_dl)\n\n'

# %%
"""
transform2 = transforms.Compose(
    [transforms.Resize((224, 224)),
     transforms.ToTensor()])

train_set2 = ImageFolder('C:/Users/heuma/Desktop/Master/S10/Aurea/Dataset_Kaggle_validation_Train_20-80/TRAIN/', transform=transform2)

train_dl2 = DataLoader(train_set2, batch_size, shuffle = True, num_workers = 4, pin_memory = True)

        
show_batch(train_dl2)
"""
# Out:
# "\ntransform2 = transforms.Compose(\n    [transforms.Resize((224, 224)),\n     transforms.ToTensor()])\n\ntrain_set2 = ImageFolder('C:/Users/heuma/Desktop/Master/S10/Aurea/Dataset_Kaggle_validation_Train_20-80/TRAIN/', transform=transform2)\n\ntrain_dl2 = DataLoader(train_set2, batch_size, shuffle = True, num_workers = 4, pin_memory = True)\n\n        \nshow_batch(train_dl2)\n"
